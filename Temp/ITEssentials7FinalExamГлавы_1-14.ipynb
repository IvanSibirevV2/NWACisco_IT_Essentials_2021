# %% [markdown]
# #
# Final Exam - Финальный экзамен — комбинированный (главы 1-14)

# %% [markdown]
# Какое состояние питания ACPI описывает, когда компьютер включен и ЦП работает?
#
# +S4
#
# S2
#
# S3
#
# S0
# Навигационная панель

# %% [markdown]
# 2
# Технический специалист работает на ноутбуке, и приложение не загружается. Каким может быть решение этой проблемы?
#
# +Выполнить сброс.
#
# Убедиться, что модуль Wi-Fi отключен.
#
# Проверить вентилятор на графическом процессоре.
#
# Убедиться, что функция Bluetooth не активирована.

# %% [markdown]
# 3
# Блоки питания какого типа используются чаще всего и создают отдельную цепь для непосредственного питания ЦП?
#
# ATX
#
# EPS12V
#
# AT
#
# +ATX12V

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# На изображении представлена схематическая топология среды виртуального сервера. Верхняя часть схемы — это 4 блока, в каждом из которых 2 узла. Верхний узел каждого блока соответствует определенному типу сервера: веб-сервер, сервер электронной почты, SQL-сервер и файловый сервер. Нижние узлы блоков помечены как «ОС Windows». В нижней части схемы вы видите еще один блок с 2 узлами. Здесь верхний узел обозначен как гипервизор, а нижний — как оборудование. От каждого из 4 блоков в верхней части схемы проведены линии к гипервизору в нижней части.Посмотрите на изображение. Какие 2 программных гипервизора совместимы с представленной на изображении средой виртуализации? (Выберите два варианта.)
#
# Oracle VirtualBox
#
# Virtual PC
#
# +VMware vSphere
#
# +Oracle VM Server
#
# VMware Workstation

# %% [markdown]
# 5
# Преподавательский состав, функциональные отделы и студенты учебного заведения пользуются решением Microsoft Office 365 и службами электронной почты. Системы хранения данных, специализированные приложения и сервисы Microsoft Active Directory размещены на виртуальных серверах, арендуемых в локальном ЦОД. Для простоты аутентификации и авторизации в обеих средах реализован механизм единого входа. Управление доступом осуществляется из локальной инфраструктуры. Какой способ внедрения облачных услуг используется в учебном заведении?
#
# Гибридное облако
#
# Облако сообщества
#
# +Частное облако
#
# Общедоступное облако

# %% [markdown]
# 6
# Пользователи в отделе продаж хотели бы отправлять документы на печать с ноутбуков и планшетов. Какие 2 технологии беспроводного доступа необходимо искать ИТ-специалисту в списке технических характеристик нового принтера для отдела продаж? (Выберите два варианта.)
#
# +Стандарт 802.11
#
# +ZigBee
#
# NFC
#
# Сотовая связь
#
# Bluetooth

# %% [markdown]
# 7
# Офисных сотрудников в компании, занимающейся разработкой ПО, временно переводят в другое крыло здания для проведения работ в освободившемся помещении. Сетевое устройство какого типа необходимо установить, чтобы пользователи могли без труда подключаться к корпоративной сети с любых смартфонов, планшетов и ноутбуков?
#
# Сетевой коммутатор
#
# +Точка доступа
#
# Концентратор или повторитель
#
# Модем

# %% [markdown]
# 8
# Выездной ИТ-специалист пытается решить проблему с производительностью приложений на ноутбуке заказчика. Он выполняет резервное копирование данных заказчика, после чего заменяет модули памяти в ноутбуке на заведомо исправные. Это не помогает устранить проблему. Какие 2 действия техническому специалисту следует предпринять дальше? (Выберите два варианта.)
#
# Эскалировать проблему специалисту технической поддержки следующего уровня.
#
# Начать локализацию следующей наиболее вероятной причины.
#
# +Задокументировать факт, что ожидаемое решение не дало эффекта.
#
# +Повторно установить исходные модули памяти.
#
# Позвонить в службу технической поддержки производителя ноутбука.

# %% [markdown]
# 9
# Каковы 2 отличительные особенности сопел 3D-принтеров с нагревателями? (Выберите два варианта.)
#
# Сопла с нагревателями предназначены для продления срока службы принтера и не требуют замены.
#
# +Сопла с нагревателями раскаляются до различных температур в зависимости от используемого типа нитей.
#
# Температура сопел с нагревателями при работе одинакова (190 °C) независимо от выбранного типа материала.
#
# Замена сопел с нагревателями может быть сложной и длительной процедурой.
#
# +Сопла с нагревателями считаются расходными материалами и требуют замены в ходе планового технического обслуживания.
# Навигационная панель

# %% [markdown]
# 10
# Технический специалист переводит новую колонку Bluetooth в режим обнаружения, следуя инструкциям в руководстве производителя. Данные какого типа колонка в этом режиме должна отправлять на ноутбук при сопряжении?
#
# +Имя устройства и сведения о модуле Bluetooth
#
# Имя и номер телефона пользователя
#
# PIN-код для создания подключения по Bluetooth и идентификатор устройства
#
# Параметры протокола и радиочастота

# %% [markdown]
# Посмотрите на изображение. Технический специалист создает загрузочный жесткий диск USB и загружает на него операционную систему Linux. После перезагрузки компьютера ОС Linux не запускается. Вместо этого начинает мигать индикатор оптического дисковода, а затем загружается ОС Windows. Что нужно сделать для автоматической загрузки компьютера с жесткого диска USB, если он подключен?
#
# +Переместить вариант загрузки с жесткого диска USB на первое место в списке.
#
# Переместить варианты загрузки с дисковода CD/DVD и жесткого диска на последние места в списке.
#
# Переместить вариант загрузки с USB-накопителя на первое место в списке.
#
# Переместить вариант загрузки с дисковода CD/DVD на последнее место в списке.

# %% [markdown]
# 12
# Накопители какого типа имеют большую емкость и могут обеспечить исключительно быструю загрузку?
#
# +SSHD
#
# SSD
#
# Жесткий диск
#
# DVD

# %% [markdown]
# Посмотрите на изображение. Сотрудник из отдела по расчету заработной платы открыл общий доступ по сети к локальному принтеру HP OfficeJet Pro 8110 в Windows 10. Что нужно сделать другим пользователям Windows 10 из отдела по расчету заработной платы, чтобы печатать свои документы на общем принтере?
#
# Ничего. Общий принтер автоматически появится в списке Устройства и принтеры при входе в систему.
#
# +В разделе Выберите принтер нажать Добавить принтер и выбрать HP OfficeJet Pro 8110 в отделе по расчету заработной платы .
#
# Активировать функцию Общий доступ к файлам и принтерам в меню Центр управления сетями и общим доступом > Дополнительные параметры общего доступа .
#
# Загрузить и установить последнюю версию драйвера HP OfficeJet Pro 8110 driver для Windows 10 с веб-сайта HP.
# Навигационная панель

# %% [markdown]
# 14
# Какой тип модулей из семейства SDRAM DDR имеет максимальную тактовую частоту и потребляет минимальный объем питания?
#
# DDR2 SDRAM
#
# SDRAM DDR3
#
# +SDRAM DDR4
#
# SDRAM GDDR5

# %% [markdown]
# 15
# Каковы 2 отличительные характеристики многоядерных процессоров? (Выберите два варианта.)
#
# Несколько одноядерных процессоров потребляют меньше питания и вырабатывают меньше тепла, чем один многоядерный.
#
# +Для повышения производительности в многоядерных процессорах любого типа кэш-память уровней 2 и 3 используется как общий ресурс.
#
# Многоядерные процессоры могут обрабатывать команды быстрее, чем одноядерные.
#
# +Использование многоядерных процессов повышает быстродействие ряда приложений, например игр и программ для редактирования видео.
#
# Каждое из ядер многоядерного процессора обменивается данными с зарезервированным ОЗУ по независимому каналу.
# Навигационная панель

# %% [markdown]
# 16
# Зачем техническому специалисту по обслуживанию сетей может потребоваться во время начальной установки изменить IP-адрес беспроводного маршрутизатора на другой частный IP-адрес?
#
# Чтобы пользователи могли указать имя сети в беспроводных клиентах вручную.
#
# Чтобы дополнить механизм защиты и шифрования учетных данных в сетевом режиме.
#
# +Чтобы снизить вероятность подключения к маршрутизатору с использованием параметров по умолчанию.
#
# Чтобы ограничить число устройств и пользователей с правом подключаться к данной беспроводной сети.
#
# Чтобы настроить маршрутизатор в качестве сервера DHCP для сети и для выполнения преобразования NAT.
# Навигационная панель

# %% [markdown]
# 17
# Выездного технического специалиста попросили проверить исправность ноутбука руководителя, который иногда работает из дома. Специалист видит, что изображение на экране ноутбука мерцает и кажется тусклым, хотя на другом дисплее, подключенном к док-станции ноутбука, выглядит нормально. На какие 2 проблемы могут указывать наблюдаемые техническим специалистом признаки? (Выберите два варианта.)
#
# Неисправен выключатель ЖК-дисплея.
#
# Ноутбук перегрелся.
#
# Возможно, начинает изнашиваться инвертор.
#
# +Произошел сбой графического процессора.
#
# +Система подсветки требует настройки или начинает изнашиваться.

# %% [markdown]
# Какие 3 типа внешних портов используются для подключения к компьютеру внешнего накопителя? (Выберите 3 варианта.)
#
# HDMI
#
# +eSATA
#
# DVI
#
# +USB
#
# +Thunderbolt
#
# SATA

# %% [markdown]
# Техническому специалисту необходимо заменить блок питания. Какие 2 характеристики необходимо учитывать при выборе новой модели? (Выберите два варианта.)
#
# Выходное напряжение (должно составлять менее 3 В)
#
# Поддержка ИБП
#
# +Мощность
#
# Поддержка интерфейса eSATA
#
# +Габариты

# %% [markdown]
# 20 Какие 3 фактора необходимо учитывать при покупке новой материнской платы? (Выберите 3 варианта.)
# 20
# Какие 3 фактора необходимо учитывать при покупке новой материнской платы? (Выберите 3 варианта.)
#
# Новая материнская плата должна быть выпущена тем же производителем, что и имеющаяся.
#
# +На имеющемся блоке питания должны быть разъемы, подходящие для установки новой материнской платы.
#
# +Разъем под ЦП и чипсет на новой материнской плате должны соответствовать имеющейся модели ЦП.
#
# Новая материнская плата должна поддерживать ту же версию UEFI BIOS, что и предыдущая.
#
# Новая материнская плата должна быть выпущена тем же производителем, что и имеющийся корпус.
#
# +Новая материнская плата должна помещаться в имеющийся корпус.
# Навигационная панель

# %% [markdown]
# ![image.png](attachment:image.png)
# На изображении представлен снимок экрана с разделом панели управления «Устройства и принтеры».  В верхней части находятся 5 устройств: «Универсальный монитор не PnP», микрофон (устройство с поддержкой High Definition Audio Device), динамики (устройство с поддержкой High Definition Audio Device), планшет USB и значок компьютера VM-WIN10-64-EDU.  На нижней панели 4 принтера: HP OfficeJet Pro 8110, «Печать в PDF (Майкрософт)», «Средство записи XPS-документов (Майкрософт)» и OneNote для Windows 10.  Рядом с устройством «Печать в PDF (Майкрософт)» расположен зеленый кружок с галочкой.Посмотрите на изображение. Пользователь обращается в службу поддержки и сообщает о проблеме с принтером. Он утверждает, что после выбора в меню функции «Печать» появляется диалоговое окно с требованием ввести имя файла. После ввода имени файла документ на подключенном принтере HP не печатается. В чем причина проблемы, с которой столкнулся пользователь?
#
# +В качестве принтера по умолчанию выбран виртуальный принтер.
#
# Принтер HP недоступен по сети.
#
# Загружен неподходящий драйвер принтера.
#
# Принтер HP выключен или не подсоединен.

# %% [markdown]
# В службу поддержки обращается заказчик с проблемой, которая возникла при попытке установить Windows 10 с диска, предоставленного ИТ-отделом. При перезагрузке компьютера вместо запуска ОС Windows снова появляется экран установщика операционной системы. Какую причину ошибки ИТ-специалист должен рассматривать как наиболее вероятную?
#
# +Заказчик забыл извлечь диск из оптического дисковода.
#
# В BIOS неправильно задан порядок загрузки.
#
# Установка Windows 10 завершилась ошибкой.
#
# Жесткий диск компьютера начал изнашиваться.
# Навигационная панель

# %% [markdown]
# Какие 2 особенности имеют сетевые адреса? (Выберите два варианта.)
#
# +Чтобы устройства могли обмениваться данными через Интернет, необходим допустимый общедоступный адрес IPv4 или IPv6.
#
# Для динамического назначения MAC- и IP-адресов подключенным к сети устройствам используется протокол DHCP.
#
# Статически назначенный IP-адрес будет действителен в любой сети, к которой подключается устройство.
#
# При перемещении между сетями Ethernet MAC-адреса устройств меняются.
#
# +MAC-адрес называют также физическим адресом, так как он присваивается сетевому адаптеру и не меняется.

# %% [markdown]
# Каковы 2 отличительные характеристики протоколов, используемых в стеке TCP/IP? (Выберите два варианта.)
#
# При работе со всеми вкладками, одновременно открытыми в веб-браузере, на транспортном уровне используется один и тот же исходный порт.
#
# IP-протокол уровня Интернета имеет встроенные механизмы для передачи и приема данных с надлежащим уровнем надежности.
#
# +Если от целевого компьютера в течение заданного периода времени не поступает подтверждение, механизмы TCP передают данные повторно.
#
# Номера портов назначения TCP и UDP создаются устройством-отправителем динамически для отслеживания ответов на запросы.
#
# +Протокол UDP используется при необходимости передать приложение как можно скорее, даже если некоторые данные будут потеряны.
# Навигационная панель

# %% [markdown]
# Почему для игровых станций или компьютеров общего назначения лучше выбирать память без буферизации?
#
# +Из блоков памяти без буферизации данные могут считываться напрямую, благодаря чему достигается быстродействие большее, чем может обеспечить буферизованная память.
#
# Дополнительная контрольная электросхема в модулях ОЗУ без буферизации ускоряет считывание данных из памяти.
#
# Контрольные микросхемы, встроенные в модули ОЗУ без буферизации, позволяют контроллеру памяти управлять большими объемами ОЗУ.
#
# Буферизованная память не позволяет устанавливать большие объемы ОЗУ, необходимые для игровых компьютеров.

# %% [markdown]
# Посмотрите на изображение. Платы адаптеров какого типа должны для установки дополнительного охлаждения иногда иметь форм-фактор с 2 разъемами, даже если оснащены только 1 разъемом PCIe x16?
#
# Адаптер беспроводной связи
#
# Графическая плата
#
# +видеокарта
#
# Контроллер USB-C

# %% [markdown]
# Пользователи в компании познакомились с производительностью сети. После изучения ИТ-специалисты определили, что злоумышленник использует таблицу слов, которая потенциально может быть использована в качестве пароля. В чем заключается тип сетевой атаки?
#
# +по словарю
#
# лавина запросов SYN
#
# Радужная таблица
#
# Неизученная уязвимость

# %% [markdown]
# Что из нижеперечисленного является точным описанием технологии асимметричного шифрования?
#
# +Это способ шифрования, в котором для шифрования/дешифрования данных применяется пара из открытого и закрытого ключа.
#
# Это способ шифрования, применяющий одинаковые ключи на обоих концах соединения для создания VPN.
#
# Это способ, которым шифруются данные, пересылаемые по VPN.
#
# Это способ шифрования, при котором трафик на разных концах соединения сличается, чтобы исключить его модификацию.
# Навигационная панель

# %% [markdown]
# Технический специалист получил запрос от супервизора на то, чтобы рекомендовать решение для обеспечения безопасности для компании, которая хочет, чтобы устройство выполняло мониторинг входящего и исходящего трафика, а вредоносные действия прекращались. Какой метод безопасности следует рекомендовать техническому специалисту?
#
# Используйте безопасный режим Windows.
#
# Используйте ловушкой.
#
# +Запустить сканеры уязвимостей.
#
# Приобретите IP-адрес.
# Навигационная панель

# %% [markdown]
# ![image.png](attachment:image.png)
# Посмотрите на изображение. Что можно определить по полученным выходным данным?
#
# У всех пользователей есть права на чтение, запись и запуск файлов в папках.
#
# Файлы в этом каталоге не содержат данных.
#
# +В этом каталоге хранятся 3 файла и 2 папки.
#
# У владельца, группы и других лиц есть права на чтение файла January.

# %% [markdown]
# Пытаясь найти и устранить проблему на компьютере заказчика, выездной технический специалист приходит к выводу, что справиться с ней поможет функция «Windows — восстановление». Данные какого типа не восстанавливаются при возврате к состоянию на момент последней точки восстановления с помощью функции «Windows — восстановление»?
#
# Параметры установленных приложений
#
# +Пользовательские файлы
#
# Файлы операционной системы
#
# Записи в реестре
#
# Драйверы устройств

# %% [markdown]
# Перед установкой последней версии ПО для управления принтером ИТ-специалист создает в Windows 10 точку восстановления. Во время установки происходит ошибка, и теперь принтер отображается как недоступный. С помощью какого инструмента Windows технический специалист может устранить последствия неудачной установки и восстановить предыдущее состояние системы, не затрагивая файлы и настроенные параметры пользователя?
#
# Редактор реестра
#
# +Восстановление системы
#
# Окно «Резервное копирование и восстановление» в
#
# История файлов

# %% [markdown]
# Какая встроенная служебная программа на компьютере Mac OS X предназначена для резервного копирования дисков?
#
# Deja Dup
#
# Finder
#
# +Time Machine
#
# Disk Utility

# %% [markdown]
# ИТ-директор компании поручает специалистам внедрить шифрование данных на корпоративных ноутбуках. Специалисты приходят к выводу, что лучше всего подойдет шифрование всех жестких дисков с помощью Windows BitLocker. Назовите два элемента, которые необходимы для внедрения такого решения. (Выберите два варианта.)
#
# +TPM
#
# +как минимум два тома
#
# USB-накопитель
#
# резервная копия
#
# управление паролями
#
# EFS

# %% [markdown]
# Заказчик приносит компьютер, который запрашивает пароль при включении даже до загрузки операционной системы. Пароль какого типа включен?
#
# многофакторный
#
# синхронный
#
# сеть
#
# +BIOS
#
# вход в систему

# %% [markdown]
# Технический специалист хочет развернуть ОС Windows 10 Pro на нескольких ПК с помощью процесса удаленной установки по сети. Сначала технический специалист подключает новые ПК к сети и выполняет на них загрузку. Однако развертывание завершается сбоем, так как целевым ПК не удается взаимодействовать с сервером развертывания. Почему это происходит?
#
# SID не был изменен в файле образа.
#
# В файле образа загружены неправильные сетевые драйверы.
#
# Перед созданием файла образа Sysprep не использовался.
#
# +В новых ПК платы сетевых адаптеров не поддерживают PXE.
# Навигационная панель

# %% [markdown]
# Какую услугу предоставляет ресурс PRINT$?
#
# Он предоставляет сетевую папку для доступа к общедоступным принтерам.
#
# Он предоставляет группу скрытых принтеров, задания на печать на которые могут отправлять только администраторы.
#
# Он предоставляет административный общий принтер, доступный для всех учетных записей локальных пользователей.
#
# +Он предоставляет драйверы принтеров администраторам принтеров.
# Навигационная панель

# %% [markdown]
# Какую ситуацию можно предотвратить, создав пароль UEFI?
#
# Доступ злоумышленника к данным в сети при помощи пароля, полученного методом фишинга
#
# +Несанкционированный доступ к незаблокированному компьютеру с правами вошедшего в систему пользователя
#
# Установка клавиатурного шпиона для получения учетных данных пользователя
#
# Несанкционированное изменение порядка загрузки, в результате которого на компьютере будет запускаться другая операционная система

# %% [markdown]
# Что необходимо использовать в качестве дополнительного механизма проверки личности при настройке параметров биометрической блокировки экрана на мобильных устройствах iOS (например, Touch ID или Face ID)?
#
# +Пароль
#
# Графический ключ
#
# Связанная учетная запись электронной почты
#
# Код для разблокировки смахиванием

# %% [markdown]
# Почему при подготовке компьютера к установке операционной системы «с нуля» полное форматирование является предпочтительным по сравнению с быстрым форматированием?
#
# +Полное форматирование удаляет с диска файлы и одновременно проверяет диск на наличие ошибок.
#
# Полное форматирование — это единственный способ установки Windows 8.1 на ПК с уже установленной ОС.
#
# Полное форматирование удаляет все разделы на жестком диске.
#
# Полное форматирование использует более быструю файловую систему FAT32, а быстрое форматирование — более медленную файловую систему NTFS.

# %% [markdown]
# Конечный пользователь хочет, чтобы у него была возможность восстановить более раннюю версию созданного документа. Если программа архивации данных запущена, какая функция Windows 10 поможет пользователю вернуться к определенной версии нужного файла?
#
# Восстановление Windows
#
# Вернуть компьютер в исходное состояние
#
# Восстановление системы
#
# +История файлов

# %% [markdown]
# ИТ-отдел только что купил 15 беспроводных точек доступа для обеспечения полного беспроводного покрытия для всех 100 сотрудников в пределах компании и хочет развернуть наиболее защищенное и масштабируемое беспроводное сетевое решение. Какой метод аутентификации с открытым исходным кодом должен выполнять аутентификацию от имени всех 15 устройств беспроводной сети?
#
# TKIP
#
# WPA2-PSK
#
# TACACS+
#
# +RADIUS

# %% [markdown]
# Технический специалист устраняет проблему на ноутбуке с ОС Windows 10, зараженном вирусом, который повредил основную загрузочную запись. Технический специалист выполнил загрузку ноутбука, используя установочный носитель, и пытается его восстановить в интерфейсе командной строки. Какую команду он может использовать для восстановления испорченной основной загрузочной записи?
#
# chkdsk
#
# +bootrec /fixmbr
#
# msconfig
#
# sfc /scannow
# Навигационная панель

# %% [markdown]
# Сетевой аналитик загружает ноутбук с Windows 7 и разъемом под SIM-карту сотовой связи. Процесс загрузки в настоящее время работает на следующем шаге: ядро Windows берет на себя процесс загрузки. Какой следующий шаг будет выполняться в процессе загрузки?
#
# Ядро Windows берет на себя управление процессом загрузки.
#
# +NTOSKRNL.EXE запускает такой файл для входа в систему, как WINLOGON.EXE.
#
# WinLoad загружает два файла, составляющих ядро Windows, а именно NTOSKRNL.EXE и HAL.DLL.
#
# WinLoad считывает файлы реестра, выбирает профиль оборудования и загружает драйверы устройств.
# Навигационная панель

# %% [markdown]
# Зачем юристу использовать команду tracert ?
#
# Отображение списка интерфейсов ближайших маршрутизаторов между исходными и целевыми устройствами
#
# Проверка активности на ПК путем отображения всех активных соединений TCP на устройстве
#
# запрос доменного имени системы (DNS) для получения доменных имен и сведений о сопоставлении
#
# +Быстрая проверка подключения путем отправки сообщений эхо-запроса на место назначения и получения серии сообщений с эхо-ответом от этого адресата

# %% [markdown]
# Технический специалист обновляет множество ПК, используемых в компании. Как технический специалист должен утилизировать старую материнскую плату?
#
# Забрать домой.
#
# +Переработать в соответствии с местными нормативными требованиями.
#
# Отдать соседу.
#
# Закопать ее.

# %% [markdown]
# Технический специалист устанавливает RAID. Если RAID использует зеркалирование, какой уровень RAID используется специалистом?
#
# 6
#
# 5
#
# +1
#
# 3
# Навигационная панель

# %% [markdown]
# Технический специалист собирается начать профилактическое обслуживание корпоративного компьютера. В какой ситуации необходимо опасаться электростатических разрядов?
#
# При подключении динамиков к звуковой карте с поддержкой объемного звучания
#
# При установке ИБП
#
# +При установке процессора
#
# При установке на рабочем месте дополнительного дисплея

# %% [markdown]
# Какой термин описывает файловую систему для USB-накопителей, поддерживающих файлы размером более 4 ГБ?
#
# CDFS
#
# FAT32
#
# +exFAT
#
# NTFS

# %% [markdown]
# Сторонняя компания, специализирующаяся в сфере обеспечения безопасности, выполняет аудит системы безопасности для компании и рекомендует ее использовать Протокол удаленного рабочего стола. Какие характеристики имеет Протокол удаленного рабочего стола (RDP) компании Microsoft? (Выберите два варианта.)
#
# +RDP использует шифрованный сеанс связи.
#
# RDP подключается через TCP-порт 22.
#
# Для RDP требуется клиент Windows.
#
# +RDP подключается через TCP-порт 3389.
#
# RDP — это протокол сетевого виртуального терминала для командной строки.
# Навигационная панель

# %% [markdown]
# Какова разница между языком сценариев и компилируемым языком?
#
# +Языки сценариев интерпретируются и выполняются построчно в ходе исполнения сценария, в то время как компилируемые языки должны преобразовываться в исполняемый код.
#
# Компилируемые языки выполняются операционной системой, в то время как языки сценариев — центральным процессором.
#
# Компилируемые языки выполняются интерпретатором команд, в то время как языки сценариев — центральным процессором.
#
# Языки сценариев нужно преобразовывать в исполняемый код с помощью компилятора, в то время как компилируемые языки интерпретируются по мере их выполнения.

# %% [markdown]
# Выездному ИТ-специалисту необходимо выполнить обслуживание компьютеров в небольшом медицинском центре Нью-Йорка. Когда он прибывает на место, администратор уточняет, знаком ли специалист с положениями закона о сохранении медицинского страхования и защите персональных данных о состоянии здоровья граждан (HIPAA). Какие 2 ситуации приравниваются к распространению закрытой медицинской информации и могут потенциально привести к наложению серьезных штрафов за нарушение HIPAA? (Выберите два варианта.)
#
# +Создание резервной копии данных о пациентах центра для воспроизведения проблем на сервере в офисе службы ИТ-поддержки
#
# +Отправка снимков экрана с различными медицинскими картами, где появились сообщения об ошибках, техническому специалисту 2-го уровня
#
# Отправка техническому специалисту по поддержке программного обеспечения текста ошибок, появляющихся при просмотре медицинских карт
#
# Звонок в службу поддержки программного обеспечения и описание проблемы, возникающей при печати медицинских карт
#
# Наблюдение за тем, как администратор воспроизводит проблему, используя копию базы данных центра с тестовыми данными
# Навигационная панель

# %% [markdown]
# Что используется для контроля за незаконным применением программного обеспечения и содержимого?
#
# +управление цифровыми правами
#
# лицензионное соглашение с конечным пользователем
#
# соглашение об уровне обслуживания
#
# процедура учета, хранения и передачи доказательств
