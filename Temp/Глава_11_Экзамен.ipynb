# %% [markdown]
# Технический специалист работает на ПК с ОС Windows 10, который периодически зависает после обновления драйвера. Служба восстановления системы была выключена. Какой вариант можно использовать в этом случае без потери данных или приложений?
# ![image.png](attachment:image.png)

# %% [markdown]
# Компания внедряет беспроводную сеть и использует беспроводные устройства в корпоративной среде. Какие методы аутентификации на сервере компания должна предусмотреть в рамках проекта беспроводной сети? (Выберите два варианта.)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IT Essentials (Версия 7.00) - Курс IT Essentials 7.0, экзамен по главе 11
# Дата сдачи экзамена: 08/19/2021 01:51 PM GMT+0300
# Знания в конкретной области - стандартный балл
# Макс. кол-во баллов: 38
#
# Заработанные баллы: 20
#
# Процентное отношение: 52,6%
#
# На основании ваших ответов на вопросы экзамена вы получили следующие рекомендации:
#
# Индивидуальная обратная связь
# Обратная связь по теме
# Обратите внимание, что по некоторым вопросам рекомендации могут быть недоступны.
#
# Программное обеспечение. Windows. Системы
# Макс. кол-во баллов: 9
#
# Заработанные баллы: 4
#
# Процентное отношение: 44,4%
#
# Программное обеспечение. Windows. Интерфейс командной строки
# Макс. кол-во баллов: 6
#
# Заработанные баллы: 3
#
# Процентное отношение: 50,0%
#
# Программное обеспечение. Windows. Панели управления
# Макс. кол-во баллов: 7
#
# Заработанные баллы: 3
#
# Процентное отношение: 42,9%
#
# Программное обеспечение. Windows. Возможности подключения
# Макс. кол-во баллов: 7
#
# Заработанные баллы: 5
#
# Процентное отношение: 71,4%
#
# Программное обеспечение. Windows. Управление
# Макс. кол-во баллов: 9
#
# Заработанные баллы: 5
#
# Процентное отношение: 55,6%
#
# Программное обеспечение. Windows. Служебные программы и инструменты
# Макс. кол-во баллов: 0
#
# Заработанные баллы: 0
#
# Процентное отношение: 0,0%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# м

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---------------------

# %% [markdown]
# ИТ-специалист обращается в службу поддержки и сообщает о следующей ситуации. «Я добавил новый ПК в локальную сеть. Я могу отправлять эхо-запросы на другие устройства в своей локальной сети, но не на удаленные устройства.» Что ему может посоветовать служба поддержки?
# ![image.png](attachment:image.png)

# %% [markdown]
# Для создания файла образа ОС Windows на одной из рабочих станций, работающих под управлением Windows 10, технический специалист использует средство Microsoft «Система обслуживания образов развертывания и управления ими» (DISM). Когда технический специалист пытается клонировать другую рабочую станцию с помощью файла образа, то по окончании процедуры эта станция сообщает о проблемах связи по сети. Какова возможная причина этой проблемы?
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Технический специалист хочет просматривать все процессы, выполняемые для активного пользователя на ПК с ОС Windows 10. Какой вариант для этого необходимо выбрать в диспетчере задач Windows?
# ![image.png](attachment:image.png)

# %% [markdown]
# Технический специалист выполняет диагностику ПК с ОС Windows 10, где зависло окно Internet Explorer. Какую команду ему можно выполнить с правами администратора в командной строке, чтобы завершить зависший процесс Internet Explorer?
# ![image.png](attachment:image.png)

# %% [markdown]
# ИТ-отдел только что купил 15 беспроводных точек доступа для обеспечения полного беспроводного покрытия для всех 100 сотрудников в пределах компании и хочет развернуть наиболее защищенное и масштабируемое беспроводное сетевое решение. Какой метод аутентификации с открытым исходным кодом должен выполнять аутентификацию от имени всех 15 устройств беспроводной сети?
# ![image.png](attachment:image.png)

# %% [markdown]
# Пользователь пытается получить доступ к общедоступному принтеру, подключенному к ПК с ОС Windows 10, но не может это сделать. Какую учетную запись для этого необходимо использовать?
# ![image.png](attachment:image.png)

# %% [markdown]
# Пользователь ПК с ОС Windows 10 хочет автоматически синхронизировать профиль пользователя с различными устройствами, работающими под управлением Windows 10, которыми владеет этот пользователь. Как пользователь может это делать?
# ![image.png](attachment:image.png)

# %% [markdown]
# Технический специалист хочет подготовить режим аварийного восстановления для компьютеров в сети. Сеть включает в себя различные настольные компьютеры и ноутбуки различных производителей. Все компьютеры работают под управлением 32- или 64-разрядной версии ОС Windows 10 Pro. Как технический специалист должен подготовить носитель для восстановления системы?
# ![image.png](attachment:image.png)

# %% [markdown]
# Пользователь в корпоративной среде сообщает, что после обновления Windows компьютер с ОС Windows, используемый сотрудниками по совместительству, медленно работает. Что должен сделать технический специалист в этой ситуации? (Выберите два варианта.)
# ![image.png](attachment:image.png)

# %% [markdown]
# Технический специалист выполняет диагностику ПК с ОС Windows 10, процедура запуска которого выполняется очень медленно. Ему нужно выяснить, какие приложения пользователя вызывают наибольшую задержку при запуске ПК. Какой инструмент для этого необходимо использовать?
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Технический специалист изменяет длину локального пароля пользователя до пяти символов, используя оснастку «Локальная политика безопасности». Технический специалист пытается создать пароль «dave» для учетной записи локального пользователя «dave», но это не удается, так как не соблюдаются требования к сложности пароля для ОС Windows 10. Какой пароль будет соответствовать требованиям?
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Пользователю нужно отобразить список текущих процессов, выполняющихся на локальном или удаленном компьютере. Какую команду Windows ему лучше всего использовать для этого?
# ![image.png](attachment:image.png)

# %% [markdown]
# -------------------------------

# %% [markdown]
# IT Essentials (Версия 7.00) - Промежуточный экзамен по главам 10-11 курса ITE 7.0.
# Дата сдачи экзамена: 08/19/2021 03:49 PM GMT+0300
# Знания в конкретной области - стандартный балл
# Макс. кол-во баллов: 24
#
# Заработанные баллы: 22
#
# Процентное отношение: 91,7%
#
# На основании ваших ответов на вопросы экзамена вы получили следующие рекомендации:
#
# Индивидуальная обратная связь
# Обратная связь по теме
# Обратите внимание, что по некоторым вопросам рекомендации могут быть недоступны.
#
# Программное обеспечение. Windows. Панели управления
# Макс. кол-во баллов: 4
#
# Заработанные баллы: 4
#
# Процентное отношение: 100%
#
# Программное обеспечение. Windows. Системы
# Макс. кол-во баллов: 2
#
# Заработанные баллы: 2
#
# Процентное отношение: 100%
#
# Безопасность. Управление. Защита ресурсов
# Макс. кол-во баллов: 2
#
# Заработанные баллы: 2
#
# Процентное отношение: 100%
#
# Программное обеспечение. Windows. Интерфейс командной строки
# Макс. кол-во баллов: 6
#
# Заработанные баллы: 4
#
# Процентное отношение: 66,7%
#
# Программное обеспечение. Windows. Служебные программы и инструменты
# Макс. кол-во баллов: 8
#
# Заработанные баллы: 8
#
# Процентное отношение: 100%
#
# Программное обеспечение. ОС компьютера. Требования
# Макс. кол-во баллов: 0
#
# Заработанные баллы: 0
#
# Процентное отношение: 0,0%
#
# Программное обеспечение. Windows. Управление
# Макс. кол-во баллов: 2
#
# Заработанные баллы: 2
#
# Процентное отношение: 100%
#
# Программное обеспечение. Windows. Возможности подключения
# Макс. кол-во баллов: 2
#
# Заработанные баллы: 2
#
# Процентное отношение: 100%

# %% [markdown]
# ![image.png](attachment:image.png)
