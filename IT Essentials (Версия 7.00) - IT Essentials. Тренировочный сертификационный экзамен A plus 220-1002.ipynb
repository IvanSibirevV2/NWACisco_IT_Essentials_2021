# %% [markdown]
# 1) Компания недавно завершила внедрение Active Directory, и теперь рабочая станция не может подключиться к сетевому ресурсу. Технический специалист произвел корректирующее действие, изменив параметры групповой политики. Какую команду должен использовать технический специалист, чтобы синхронизировать рабочую станцию с новыми параметрами?
# - rstrui
# - runas
# - tasklist
# - gpresult
# - $+$gpupdate

# %% [markdown]
# 2) Какой тип файловой системы позволяет работать с файлами размером более 5 Гбайт и наиболее часто используется на внутренних жестких дисках?
# - +NTFS
# - FAT64
# - CDFS
# - FAT32

# %% [markdown]
# 3
# Аудит безопасности в отделе кадров показал, что большинство сотрудников, покидая рабочие места ненадолго, оставляют конфиденциальную информацию на экране. Какой элемент панели управления Windows следует использовать, чтобы через несколько минут бездействия монитор отображал экранную заставку и для возвращения к работе система предлагала пользователю пройти повторную аутентификацию?
#
# Межсетевой экран Windows
#
# Центр управления сетями и общим доступом
#
# +Персонализация
#
# Диспетчер устройств

# %% [markdown]
# 4
# Какую служебную программу Windows можно использовать для планирования регулярного резервного копирования в целях профилактического обслуживания?
#
# +Планировщик заданий Windows
#
# Восстановление системы
#
# Очистка диска
#
# Диспетчер задач Windows
# Навигационная панель

# %% [markdown]
# 5
# Учащийся сообщает преподавателю, что на новый персональный ноутбук поступает много нежелательных электронных сообщений. Какова возможная причина данной проблемы?
#
# Ноутбук необходимо обновить до последней версии ОС.
#
# +На новом ноутбуке не установлено антивирусное программное обеспечение или ПО для борьбы со спамом.
#
# Учащийся потратил слишком много времени на разных сайтах в Интернете.
#
# Школьный почтовый сервер функционирует ненормально.
# Навигационная панель

# %% [markdown]
# 6
# Торговый представитель направляется на машине в город, чтобы посетить несколько офисов заказчиков. Он замечает, что смартфон расходует напряжение аккумулятора быстрее, чем обычно. Какова возможная причина данной проблемы?
#
# Смартфон не был полностью заряжен.
#
# Зарядное устройство функционирует неправильно.
#
# +Смартфон перемещается между вышками сотовой связи.
#
# В районе недостаточно точек доступа Wi-Fi.
# Навигационная панель

# %% [markdown]
# 7
# Пользователь обращается в службу поддержки и сообщает, что на экране появляется предупреждение системы безопасности о попытке проникновения вредоносного ПО на ПК. Что технический специалист должен предложить сделать пользователю?
#
# Закройте ПО почтового клиента.
#
# +Просканируйте ПК, чтобы удалить вредоносное ПО.
#
# Включите межсетевой экран Windows.
#
# Немедленно отключите сетевое соединение.
# Навигационная панель

# %% [markdown]
# 8
# ИТ-специалист в компании из сферы обслуживания обеспечивал обширную удаленную ИТ-поддержку по развертыванию продукта для заказчика. По окончании контракта на этого специалиста была подана жалоба. В ней было отмечено, что он не соблюдал политику компании, так как отправлял незапрашиваемые электронные письма об услугах и продуктах, не имеющих отношения к контракту. Что этот специалист должен был сделать по-другому? (Выберите два варианта.)
#
# ИТ-специалист должен был использовать шифрование для сокрытия назначения электронных писем.
#
# ИТ-специалист должен был запросить разрешение у руководителя на отправку электронных писем заказчика.
#
# ИТ-специалист должен был добавить заказчика в круговое письмо с несколькими получателями.
#
# +ИТ-специалист должен был спросить у заказчика, интересно ли будет последнему получать информацию о других новых услугах и продуктах.
#
# ИТ-специалист должен был ознакомиться с политикой компании относительно персональной связи с заказчиками в рабочее время.
# Навигационная панель

# %% [markdown]
# 9
# Секретарь-референт пытается подключить Bluetooth-клавиатуру и Bluetooth-мышь к компьютеру. Мышь работает нормально, а клавиатура не работает. Какие две проблемы могут вызывать такую ситуацию? (Выберите два варианта.)
#
# +Клавиатура находится слишком далеко от компьютера.
#
# Отключен модуль Wi-Fi.
#
# +Разряжен аккумулятор клавиатуры.
#
# Случайно нажата клавиша Num Lock.
#
# Отключен модуль Bluetooth.
# Навигационная панель

# %% [markdown]
# 10
# Инженеру нужно безвозвратно уничтожить данные на некоторых дисках перед их утилизацией. Каков оптимальный способ выполнения этой задачи?
#
# Перезаписать диски.
#
# Выполнить полное форматирование.
#
# Разбить жесткие диски на разделы.
#
# +Разбить пластины диска молотком.

# %% [markdown]
# 11
# В одном из магазинов, расположенном в торговом центре, используется беспроводная сеть для предоставления доступа к Интернету для трех планшетных компьютеров. В качестве метода аутентификации в направлении к беспроводному маршрутизатору используется 128-разрядный протокол WEP. Недавно сотрудники магазина стали замечать, что соединение с Интернетом стало работать медленнее. Администратор сети из торгового центра проверяет журналы беспроводного маршрутизатора и обращает внимание на то, что с маршрутизатором связано много устройств, не относящихся к данному магазину. Что должен сделать администратор сети для повышения уровня безопасности доступа к беспроводной сети? (Выберите два варианта.)
#
# Используйте 152-разрядный протокол WEP.
#
# +Используйте функцию фильтрации MAC-адресов.
#
# Используйте SSID, содержащий 32 символа.
#
# Убедитесь, что общий ключ генерируется в произвольном порядке.
#
# +Вместо WEP используйте протокол WPA2.
# Навигационная панель

# %% [markdown]
# 12
# При помощи какой функции администратор может предотвратить подключение неавторизованных пользователей к беспроводной точке доступа?
#
# программный межсетевой экран
#
# +фильтрация по MAC-адресам
#
# прокси-сервер
#
# шифрование WPA
# Навигационная панель

# %% [markdown]
# 13
# Что должен сделать инженер в первую очередь, перед тем как разобрать компьютер?
#
# +Отключить питание компьютера.
#
# Отключить компьютер от сети.
#
# Отключить внешние устройства, такие как мышь.
#
# Извлечь блок питания.
# Навигационная панель

# %% [markdown]
# 15
# Инженер службы поддержки имеет дело с раздраженным заказчиком. Какие два подхода к заказчику должен использовать инженер в этом случае? (Выберите два варианта.)
#
# Сразу отправить заказчика к специалисту более высокого уровня.
#
# +Дать заказчику возможность рассказать о проблеме, не перебивая его.
#
# Задать заказчику вопросы на посторонние темы, чтобы отвлечь его от проблемы.
#
# Отвечать заказчику в том же духе.
#
# +Перевести разговор на решение проблемы.

# %% [markdown]
# 14
# Инженер замечает, что некоторое приложение не реагирует на команды и что компьютер медленно реагирует при открытии приложений. Какое средство администрирования лучше всего подойдет, чтобы заставить приложение, которое не отвечает, принудительно освободить системные ресурсы?
#
# Восстановление системы
#
# Просмотр событий
#
# +Диспетчер задач
#
# Установка и удаление программ
# Навигационная панель

# %% [markdown]
# 16 Компания предоставляет посетителям на своей территории гостевое подключение к беспроводной сети. Инженер заметил, что к этой беспроводной сети подключаются внешние неавторизованные пользователи. Как можно уменьшить число несанкционированных подключений к гостевой беспроводной сети, сохранив для посетителей на территории компании возможность легко и быстро подключаться к сети самостоятельно?
# 16
# Компания предоставляет посетителям на своей территории гостевое подключение к беспроводной сети. Инженер заметил, что к этой беспроводной сети подключаются внешние неавторизованные пользователи. Как можно уменьшить число несанкционированных подключений к гостевой беспроводной сети, сохранив для посетителей на территории компании возможность легко и быстро подключаться к сети самостоятельно?
#
# Применить фильтрацию по MAC-адресам.
#
# Настроить шифрование WPA.
#
# +Отключить широковещательную рассылку идентификатора SSID.
#
# Снизить уровень мощности радиосигнала.
# Навигационная панель

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 18
# Какой вопрос является примером «открытого» вопроса, который инженер может задать при устранении проблемы, связанной с безопасностью?
#
# Открывали ли вы вложения из подозрительного сообщения электронной почты?
#
# Проводили ли вы недавно сканирование компьютера на наличие вирусов?
#
# +Какие симптомы Вы наблюдаете?
#
# Обновлено ли ваше ПО безопасности?
# Навигационная панель

# %% [markdown]
# 19
# Пользователь обнаруживает, что при запуске загруженного файла обновления Windows центр обновления Windows работает со сбоями. По какой причине это может происходить? (Выберите два варианта.)
#
# Определения вирусов устарели.
#
# +Предыдущее обновление, требуемое для текущего обновления, не установлено.
#
# Межсетевой экран Windows выключен.
#
# Жесткий диск неисправен.
#
# +Загруженный файл обновления разрушен.

# %% [markdown]
# Пользователь покупает новый смартфон и пытается использовать высококачественную гарнитуру Bluetooth на новом устройстве. Однако гарнитуру не удается подключить к смартфону. Какие настройки необходимо проверить пользователю для устранения проблемы? (Выберите три варианта.)
#
# Служба аутентификации должна быть включена.
#
# +PIN-код должен быть правильно введен.
#
# +Соединение Bluetooth на смартфоне должно быть включено.
#
# Уровень заряда аккумулятора на смартфоне должен быть выше 50%.
#
# +Гарнитура должна быть включена.
#
# USB-порт на гарнитуре должен быть исправен.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 22
# Пользователь использовал смартфон в течение нескольких часов, но теперь приложения на устройстве перестали реагировать на его действия. Что должен предпринять пользователь?
#
# Выполнить восстановление заводских настроек на мобильном устройстве.
#
# +Перезапустить устройство.
#
# Перенастроить параметры.
#
# Восстановить мобильную операционную систему из резервной копии.
# Навигационная панель

# %% [markdown]
# 23
# Программист разрабатывает сценарий, который будет тестировать условие «истина» или «ложь». Какой тип данных ему необходимо использовать?
#
# char
#
# float
#
# int
#
# +Bool
# Навигационная панель

# %% [markdown]
# 24
# Получив жалобы от пользователей, инженер обнаруживает, что веб-сервер колледжа работает очень медленно. Проверка сервера показала, что с нескольких адресов в Интернете поступает необычно большое количество TCP-запросов. Укажите источник проблемы.
#
# Сервер заражен вирусом.
#
# Предпринята атака с повторением пакетов.
#
# Недостаточная полоса пропускания для подключения к серверу.
#
# +Предпринята DDoS-атака.
# Навигационная панель

# %% [markdown]
# 25
# На всех компьютерах с ОС Windows 10 в небольшом рекламном агентстве настроена служба «Восстановление системы». Один из этих ПК был инфицирован вредоносным ПО, когда сотрудник посещал веб-сайты. ИТ-администратор сканирует систему и удаляет вредоносное ПО из папки «Объекты в карантине». Что администратор должен сделать далее для завершения процесса исправления?
#
# +Восстановите систему с помощью резервной копии.
#
# Удалите все точки восстановления.
#
# Отключите службу «Восстановление системы».
#
# Создайте точку восстановления.
# Навигационная панель

# %% [markdown]
# 26
# Назовите две рекомендации по созданию надежных паролей. (Выберите два варианта.)
#
# Используйте в паролях только прописные буквы и цифры.
#
# Пароли должны содержать только символы.
#
# +Используйте не менее восьми символов.
#
# Меняйте пароль каждый год.
#
# +Включите в пароль буквы, цифры и символы.
# Навигационная панель

# %% [markdown]
# 27
# Что нужно для подключения ноутбука с поддержкой Wi-Fi к защищенной беспроводной сети WPA?
#
# MAC-адрес
#
# имя пользователя и пароль
#
# +защитный ключ шифрования
#
# обновленный драйвер адаптера беспроводной сети
# Навигационная панель

# %% [markdown]
# 28
# Пользователь совершает покупки в торговом центре и получает уведомление на смартфоне о поступлении нового электронного письма. Пользователь задается вопросом, каким образом было доставлено это письмо, если функция использования данных выключена. Он обращает внимание на то, что смартфон подключен к кафе в торговом центре с помощью Wi-Fi. Как было установлено это соединение?
#
# Точка доступа Wi-Fi в кафе использует личные настройки WPA2.
#
# +Смартфон настроен на автоматическое подключение к доступным сетям Wi-Fi.
#
# Оператор связи для смартфона устанавливает соединения Wi-Fi в торговом центре.
#
# Точка доступа Wi-Fi в кафе использует тот же канал, что и смартфон пользователя.
# Навигационная панель

# %% [markdown]
# 29
# Клиент объясняет техническому специалисту суть проблемы с компьютером. Технический специалист понимает, в чем дело еще до того, как клиент закончил свой рассказ. Что должен сделать специалист?
#
# Попросить клиента снова описать проблему, чтобы задокументировать ее и проверить все факты.
#
# Прервать клиента и дать ему понять, что причина проблемы уже ясна.
#
# +Вежливо подождать, пока клиент закончит рассказ.
#
# Начать работу с компьютером, одновременно слушая клиента.
# Навигационная панель

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Какой тип вредоносного ПО маскируется под легальную программу?
#
# червь
#
# +Троянская программа
#
# шпионское ПО
#
# рекламное ПО
# Навигационная панель

# %% [markdown]
# 32
# Какие две меры предосторожности помогают защититься от социотехники? (Выберите два варианта.)
#
# Не допускайте заказчиков на рабочее место.
#
# +Всегда спрашивайте у неизвестных лиц удостоверения.
#
# Держите пароль в надежном месте под клавиатурой.
#
# Всегда требуйте настроить имя пользователя и пароль.
#
# +Сопровождайте всех посетителей.
# Навигационная панель

# %% [markdown]
# 33
# В какой ситуации при ремонте компьютеров используется параметр PXE?
#
# Перебои в работе системы, вызванные недавно установленным приложением.
#
# +Необходимость замены на компьютере операционной системы.
#
# Нечеткость изображения на дисплее.
#
# Отсутствие отклика при использовании мыши или клавиатуры.
# Навигационная панель

# %% [markdown]
# 34
# Пользователь сообщает техническому специалисту, что на компьютере Apple не создаются резервные копии. Что должен проверить технический специалист в первую очередь?
#
# Наличие свободного места на локальном накопителе.
#
# Правильность настройки даты и времени.
#
# Включение функции Remote Disc.
#
# +Работу приложения Time Machine.
# Навигационная панель

# %% [markdown]
# 35
# Корпорация расширяется, открывая несколько удаленных офисов по всему миру. Какую технологию следует использовать для обеспечения конфиденциальной связи и защищенного совместного доступа к сетевым ресурсам в удаленных офисах?
#
# Удаленный помощник
#
# +VPN
#
# Удаленный рабочий стол
#
# Административный общий ресурс
# Навигационная панель

# %% [markdown]
# 36
# Пользователь замечает, что некоторые программы, установленные до обновления до ОС Windows 7, больше не работают надлежащим образом. Что может сделать пользователь, чтобы решить проблему?
#
# Обновить драйвер для графической платы.
#
# Установить меньшее значение для настройки контроля учетных записей (UAC) в диалоговом окне Изменение параметров контроля учетных записей панели управления учетных записей пользователей .
#
# Изменить файловую систему на FAT16.
#
# +Перезапустить программы в режиме совместимости.

# %% [markdown]
# 37
# Пользователь обращается в службу поддержки и сообщает, что при включении питания на рабочей станции отображаются сообщения об ошибках (недопустимый системный или загрузочный диск). Когда технический специалист приходит в офис, пользователь сообщает, что накануне рабочая станция работала нормально весь день. Технический специалист проверяет рабочую станцию и убеждается, что кабель между жестким диском и материнской платой надежно подключен. Какова другая вероятная причина данной проблемы?
#
# Некоторые файлы операционной системы могут быть повреждены.
#
# +Повреждена MBR/GPT.
#
# Не удается запустить службу загрузки.
#
# Недавно установленный драйвер устройства несовместим со службой загрузки.

# %% [markdown]
# 38
# Компания заменила пять настольных компьютеров в отделе бухгалтерского учета и финансов новыми компьютерами. Планируется подарить полностью отремонтированные компьютеры некоммерческой общественной организации. Каким образом компания может гарантировать, что конфиденциальные финансовые данные будут недоступны после передачи компьютеров?
#
# Стереть данные с жестких дисков при помощи специального ПО.
#
# Удалить все файлы и каталоги на жестких дисках.
#
# Просверлить отверстия в пластинах жестких дисков.
#
# +Провести высокоуровневое форматирование жестких дисков.
# Навигационная панель

# %% [markdown]
# 39
# Пользователь совершает прогулку пешком по городскому парку. Он хочет позвонить домой, но надежный сотовый сигнал отсутствует. Какова возможная причина плохого сотового покрытия? (Выберите два варианта.)
#
# Служба определения местоположения выключена.
#
# +В районе недостаточно вышек сотовой связи.
#
# Гарнитура Bluetooth не сопряжена.
#
# +Пользователь находится между зонами покрытия оператора связи.
#
# Ближайшая точка доступа Wi-Fi находится очень далеко.
# Навигационная панель

# %% [markdown]
# 40
# В какой папке обычно хранятся файлы 32-разрядных приложений на компьютере с 64-разрядной версией Windows 7?
#
# C:\Application Data
#
# +C:\Program Files (x86)
#
# C:\Program Files
#
# C:\Users
# Навигационная панель

# %% [markdown]
# 41
# Мобильный абонент скачивает и устанавливает приложение. После установки приложения мобильное устройство Android зависает. Какова причина этой проблемы?
#
# Для нормального функционирования приложения требуются дополнительные приложения.
#
# +Приложение несовместимо с устройством.
#
# Приложение необходимо обновить.
#
# Мобильную ОС необходимо заменить.

# %% [markdown]
# 42
# Что дает виртуальная память операционной системе?
#
# Создание виртуальных разделов на жестком диске.
#
# Дополнительное пространство для хранения данных.
#
# Увеличение скорости доступа к ОЗУ.
#
#
# +Временное хранение данных до освобождения в ОЗУ достаточного места для их обработки.
# Навигационная панель

# %% [markdown]
# 43
# Когда пользователь пытается запустить программу, появляется сообщение об отсутствующей или поврежденной библиотеке DLL. Как можно устранить эту проблему?
#
# С помощью команды msconfig настройте параметры запуска для программы.
#
# Запустите средство восстановления запуска Windows.
#
# Выполните команду sfc /scannow в безопасном режиме.
#
# +Повторно установите правильные драйверы.

# %% [markdown]
# 46 Зачем администратор использует программы «Удаленный рабочий стол Windows» и «Удаленный помощник Windows»?
# 46
# Зачем администратор использует программы «Удаленный рабочий стол Windows» и «Удаленный помощник Windows»?
#
# +Для подключения к удаленному компьютеру через сеть и управления размещенными на нем приложениями и данными.
#
# Для подключения к корпоративной сети через незащищенное соединение и работу в качестве локального клиента этой сети.
#
# Для обмена файлами и презентациями с группой пользователей через Интернет.
#
# Для обеспечения безопасного удаленного доступа к ресурсам в другой сети.
# Навигационная панель

# %% [markdown]
# 45
# Пользователь обращается в службу поддержки и сообщает, что при включении питания на рабочей станции отображаются сообщения об ошибках (недопустимый системный диск или загрузочный диск). Когда технический специалист приходит в офис, пользователь сообщает, что накануне рабочая станция работала нормально весь день. Технический специалист предполагает, что повреждена запись MBR. Каким образом технический специалист может проверить и восстановить MBR?
#
# Выполните команду chkdsk .
#
# Загрузите рабочую станцию в безопасном режиме.
#
# +Выполните команду bootrec .
#
# Выполните команду sfc .
# Навигационная панель

# %% [markdown]
# 47
# Находящийся в командировке сотрудник компании подключается к беспроводной сети с открытой аутентификацией. Что он должен сделать для обеспечения безопасности конфиденциальных данных при подключении к бизнес-сервисам?
#
# Изменить параметры межсетевого экрана Windows.
#
# +Подключиться с использованием виртуальной частной сети (VPN).
#
# Изменить профиль сетевого расположения на «Общедоступная сеть».
#
# Вручную настроить IP-адрес, маску подсети и шлюз по умолчанию.
# Навигационная панель

# %% [markdown]
# 44
# При установке прикладного ПО на рабочую станцию Windows 7 отображается сообщение об ошибке, указывающее на неудачное завершение установки. Что должен сделать пользователь?
#
# +Перезапустить процесс установки с помощью служебной программы services.msc .
#
# Запустить установку в режиме совместимости.
#
# Выполнить команду bootrec /fixmbr с консоли восстановления системы.
#
# Выполнить команду chkdsk /R .
# Навигационная панель

# %% [markdown]
# 48
# Какое утверждение описывает большинство лицензий на корпоративное программное обеспечение?
#
# Пользователю разрешается установить программное обеспечение только на одном компьютере.
#
# Разработчикам разрешается изменять и совместно использовать исходный код программного обеспечения.
#
# Пользователю разрешается использовать программное обеспечение совместно с друзьями.
#
# +Компании разрешается использовать программное обеспечение в пределах кампуса.
# Навигационная панель

# %% [markdown]
# 49
# Инженер собирается установить и настроить беспроводную сеть в небольшом филиале. Какую меру безопасности инженер должен принять сразу после включения беспроводного маршрутизатора?
#
# Включить фильтрацию по MAC-адресам на беспроводном маршрутизаторе.
#
# Изменить имя пользователя и пароль, установленные на беспроводном маршрутизаторе по умолчанию.
#
# +Отключить широковещательную рассылку идентификатора SSID беспроводной сети.
#
# Настроить шифрование на беспроводном маршрутизаторе и подключенных беспроводных устройствах.

# %% [markdown]
# 50
# Пользователь сообщает о том, что на ПК с ОС Windows 10 отображается предупреждающее сообщение. В этом сообщении указывается, что ПК инфицирован вредоносным ПО. Технический специалист приезжает в офис и убеждается, что ПК отключен от всех проводных и беспроводных сетей. Что теперь должен сделать технический специалист для последующего анализа инцидента?
#
# Сохраните файлы журнала на съемном носителе.
#
# +Переместите вредоносное ПО в папку «Объекты в карантине».
#
# Загрузите ПК в безопасном режиме.
#
# Отсоедините жесткий диск.

# %% [markdown]
# 51
# Какой компонент операционной системы Linux интерпретирует команды пользователя и перенаправляет их в операционную систему?
#
# Приложение
#
# Оболочка
#
# +Интерфейс командной строки
#
# Ядро
# Навигационная панель

# %% [markdown]
# 53
# Пользователь настраивает беспроводную точку доступа и хочет, чтобы окружающие не могли обнаружить сеть. Что должен сделать пользователь?
#
# +Отключить широковещательную рассылку идентификатора SSID.
#
# Включить шифрование WPA.
#
# Настроить DNS-сервер.
#
# Настроить параметры DMZ.
# Навигационная панель

# %% [markdown]
# 52 В каком случае может потребоваться загрузка Windows 7 с USB-устройства, компакт- или DVD-диска?
# 52
# В каком случае может потребоваться загрузка Windows 7 с USB-устройства, компакт- или DVD-диска?
#
# когда необходимо разбить жесткий диск на разделы
#
# +когда необходимо восстановить систему
#
# когда необходимо удалить разделы реестра
#
# когда необходимо отключить фоновые службы
# Навигационная панель

# %% [markdown]
# 54
# Инженер успешно удалил с компьютера вредоносное ПО, но при перезагрузке системы появились сообщения об отсутствующих и поврежденных системных файлах. Какую служебную программу может использовать инженер для замены или исправления поврежденных системных файлов?
#
# SFC
#
# Fixmbr
#
# ++Fixboot
#
# ASR
#
# Regedit
# Навигационная панель

# %% [markdown]
# 56
# Компьютер успешно получает ответ на эхо-запрос за пределы локальной сети, но не может зайти на сайты из Интернета. Укажите наиболее вероятную причину этой проблемы.
#
# Брандмауэр Windows блокирует порт 23 по умолчанию.
#
# Неисправна сетевая интерфейсная плата компьютера.
#
# +Брандмауэр Windows блокирует порт 80.
#
# Параметры BIOS или CMOS блокируют доступ к веб-службам.
# Навигационная панель

# %% [markdown]
# 59
# Что из нижеперечисленного является примером веб-приложения, в котором используется многофакторная аутентификация?
#
# +Пользователь является участником крупной конференции и пытается получить доступ к Google Gmail на сайте этой конференции. Служба Gmail отправляет код проверки на смартфон пользователя.
#
# Перед входом на внутренний веб-сервер компании удаленным пользователям необходимо установить VPN-соединение с компанией.
#
# Администратору сети нужно приложить карту, чтобы получить доступ к корпоративной серверной.
#
# Пользователь выполняет вход на веб-сайт Интернет-торговли и использует кредитную карточку для оформления заказа.

# %% [markdown]
# 60
# Какой параметр нужно включить для предоставления общего доступа к принтеру в Windows 7?
#
# Брандмауэр Windows
#
# Общий доступ
#
# Общий доступ к данному принтеру
#
# +Общий доступ к файлам и принтерам
# Навигационная панель

# %% [markdown]
# 61
# Учащийся бегает трусцой в городском парке. На его смартфоне установлено приложение, отслеживающее физическую нагрузку. Учащийся получает уведомление о поступлении нового электронного письма и останавливается, чтобы его прочесть. Однако почтовое приложение реагирует очень медленно. Почему приложение медленно открывается?
#
# Смартфон неспособен дешифровать электронное письмо.
#
# +Почтовому приложению требуется большой объем ОЗУ.
#
# Специальное приложение, отслеживающее физическую нагрузку, использует услугу GPS.
#
# ОС смартфона заморожена.

# %% [markdown]
# ![image.png](attachment:image.png)
# Посмотрите на рисунок. В какой ситуации технический специалист будет использовать эту вкладку?
#
# когда устройство находится позади межсетевого экрана, и используется программное обеспечение, которому нужен доступ к удаленной сети
#
# когда устройство не будет использовать Интернет
#
# +когда ноутбук используется в офисе с протоколом DHCP, а дома — со статическим IP-адресом
#
# когда компьютер будет использовать VPN-подключение и получать доступ к Интернету, когда он подключен через VPN

# %% [markdown]
# 65
# Какое утверждение о точках восстановления верно?
#
# В точках восстановления содержатся резервные копии файлов с личными данными.
#
# +Точки восстановления следует всегда создавать, прежде чем внести изменения в систему.
#
# После использования программы восстановления системы изменение необратимо.
#
# Точки восстановления служат для восстановления поврежденных или удаленных файлов данных.
# Навигационная панель

# %% [markdown]
# 58
# Согласно политике профилактического обслуживания компании, каждые полгода для каждого компьютера необходимо создавать новую точку восстановления. Как создать точку восстановления на компьютере с ОС Windows 7?
#
# +Выбрать Пуск > Панель управления > Стандартные > Служебные > Восстановление системы > Создание точки восстановления .
#
# Правой кнопкой мыши щелкнуть на значке Мой компьютер , затем выбрать Свойства > Восстановление > Создание точки восстановления .
#
# Выбрать Пуск > Все программы > Стандартные > Служебные > Восстановление системы > Далее .
#
# Ввести в интерфейсе командной строки команду restore /cn .
# Навигационная панель

# %% [markdown]
# 66
# Пользователь хочет увеличить основной раздел, отформатированный под файловую систему NTFS, за счет незанятого пространства на жестком диске. Что должен сделать пользователь, чтобы с расширенным основным разделом можно было работать?
#
# Отформатировать диск под файловую систему FAT64.
#
# Убедиться, что диск базового типа.
#
# +Разбить новое пространство на разделы как базовый диск.
#
# Преобразовать диск в динамический.

# %% [markdown]
# 62
# Какой инструмент управления дисками сканирует наиболее важные файлы операционной системы и заменяет поврежденные?
#
# Оптимизация дисков
#
# Проверка системных файлов (SFC)
#
# Chkdsk
#
# Очистка диска
#
# +ScanDisk

# %% [markdown]
# 64
# ПК с ОС Windows пользователя был неожиданно выключен из-за внезапной потери электропитания. Пользователь сообщает, что на рабочей станции исчезли несколько файлов. Технический специалист службы поддержки предполагает, что может быть повреждена какая-то часть жесткого диска. С помощью какой программы в ОС Windows технический специалист может отсканировать жесткий диск и устранить проблему, в случае необходимости?
#
# +Дефрагментатор диска
#
# Chkdsk
#
# Очистка диска
#
# Проверка системных файлов
# Навигационная панель

# %% [markdown]
# 67
# Какую клавишу или последовательность клавиш пользователю следует нажать в процессе загрузки, чтобы при загрузке Windows использовалась последняя удачная конфигурация?
#
# F1
#
# +F8
#
# Alt-Z
#
# клавишу Windows
#
# F12
# Навигационная панель

# %% [markdown]
# 68
# Что определяет уровень поддержки, которую специалист центра обслуживания предоставляет конкретному клиенту?
#
# +Технический специалист первого уровня обеспечивает более высокий уровень поддержки, чем технический специалист второго уровня.
#
# Все клиенты получают в центре обслуживания поддержку одного уровня.
#
# Технический специалист, работающий в центре обслуживания, самостоятельно выбирает уровень поддержки в зависимости от времени, которое он может потратить на помощь клиенту.
#
# Поддержка основана на соглашении об уровне обслуживания, заключенном с данным клиентом.
# Навигационная панель

# %% [markdown]
# 69 Назовите три устройства биометрической защиты. (Выберите три варианта).
# 69
# Назовите три устройства биометрической защиты. (Выберите три варианта).
#
# +система распознавания голоса
#
# пароль
#
# ключ-брелок
#
# +сканер сетчатки
#
# смарт-карта
#
# +считыватель отпечатков пальцев
# Навигационная панель

# %% [markdown]
# 70
# Пользователь обнаружил, что одна из виртуальных машин на компьютере заражена вирусом. Какое утверждение относительно данной ситуации, вероятно, верно?
#
# +Операционная система главного компьютера необязательно заражена вирусом.
#
# Необходимо обновить антивирусную программу на главном компьютере.
#
# Операционная система главного компьютера содержит ошибку.
#
# Все виртуальные машины, работающие на главном компьютере, заражены вирусом.
# Навигационная панель

# %% [markdown]
# 71
# Какое утверждение об установке 32-разрядной операционной системы в архитектуре x64 верно?
#
# ОС может обслуживать более 128 Гбайт памяти.
#
# +Такая комбинация обеспечивает повышенную безопасность.
#
# ОС будет работать правильно.
#
# ОС всегда будет использовать все доступные ресурсы ОЗУ.
# Навигационная панель

# %% [markdown]
# 72
# Инженер занят устранением проблемы с безопасностью компьютера. Злоумышленник смог воспользоваться комьютером благодаря ненадежному паролю пользователя. Какое действие следует предпринять инженеру в качестве профилактики подобных атак?
#
# Проверить наличие новейших исправлений и обновлений ОС компьютера.
#
# +Убедиться в соблюдении политики безопасности.
#
# Проверить физическую безопасность всех офисов.
#
# Просканировать компьютер с помощью защитного ПО.

# %% [markdown]
# 73
# Пользователь получает электронное сообщение с просьбой подтвердить пароль, используемый для доступа к банковским файлам. К какому типу относится эта угроза безопасности?
#
# вирус
#
# +фишинг
#
# социотехника
#
# вредоносное ПО

# %% [markdown]
# 74
# Какие местоположения системы хранения данных содержат данные длительного хранения, которые могут использоваться специалистами по компьютерно-технической экспертизе? (Выберите два варианта.)
#
# +накопители на жестких дисках
#
# +твердотельные накопители
#
# кэш
#
# ОЗУ
#
# регистры ЦП
# Навигационная панель

# %% [markdown]
# 75
# Сторонняя компания, специализирующаяся в сфере обеспечения безопасности, выполняет аудит системы безопасности для компании и рекомендует ее использовать Протокол удаленного рабочего стола. Какие характеристики имеет Протокол удаленного рабочего стола (RDP) компании Microsoft? (Выберите два варианта.)
#
# RDP использует шифрованный сеанс связи.
#
# RDP подключается через TCP-порт 3389.
#
# RDP подключается через TCP-порт 22.
#
# RDP — это протокол сетевого виртуального терминала для командной строки.
#
# Для RDP требуется клиент Windows.
# Навигационная панель

# %% [markdown]
# 76
# Пользователь завершил проект и хочет стереть или удалить один или несколько файлов из каталога Windows. Какую команду Windows ему лучше всего использовать для этого?
#
# DISM
#
# tasklist
#
# history
#
# +del
#
# sfc
# Навигационная панель

# %% [markdown]
# 77
# Администратор обращается в службу поддержки и сообщает о следующей ситуации. «Мне нужно внести изменения в файл. Я могу его открыть, но изменения внести не могу.» Что ему может посоветовать служба поддержки?
#
# Создайте виртуальную машину с ОС, которая поддерживает определенное приложение.
#
# +Проверьте права на доступ к этому файлу.
#
# Установите для файла права на чтение и выполнение.
#
# В случае использования ОС Windows установите время ожидания простоя и блокировку экрана.

# %% [markdown]
# 78
# Технический специалист выполняет диагностику ПК с ОС Windows 10, где имеется файл .DLL для приложения, которое не было зарегистрировано. Какую для этого можно использовать административную программу командной строки или команду?
#
# type
#
# net user
#
# gpupdate
#
# +++regsvr32

# %% [markdown]
# 79
# Какое утверждение описывает основной раздел?
#
# Это часть расширенного раздела в MBR. Ее можно использовать для разделения информации в административных целях.
#
# Он часто используется для организации хранилища данных путем его разделения максимум на 23 логические секции.
#
# +Используется для загрузки операционной системы по умолчанию.
#
# Это физическая часть жесткого диска. Он может содержать операционную систему для загрузки системы и не может быть разделен.
# Навигационная панель

# %% [markdown]
# 80
# Менеджер хочет установить ОС Windows 10 непосредственно на компьютер и просит помочь с процессом установки. Какое средство или программу лучше всего ему использовать?
#
# Помощник по обновлению
#
# +Диспетчер загрузки Windows
#
# PCmover Express
#
# Приложение Get Windows 10
# Навигационная панель

# %% [markdown]
# IT Essentials (Версия 7.00) - IT Essentials. Тренировочный сертификационный экзамен A+ 220-1002
# Дата сдачи экзамена: 09/24/2021 03:53 PM GMT+0300
# Знания в конкретной области - стандартный балл
# Макс. кол-во баллов: 119
#
# Заработанные баллы: 91
#
# Процентное отношение: 76,5%
#
# На основании ваших ответов на вопросы экзамена вы получили следующие рекомендации:
#
# Индивидуальная обратная связь
# Обратная связь по теме
# Обратите внимание, что по некоторым вопросам рекомендации могут быть недоступны.
#
# Программное обеспечение. Linux and Mac.
# Макс. кол-во баллов: 3
#
# Заработанные баллы: 2
#
# Процентное отношение: 66,7%

# %% [markdown]
# Человеческий фактор. Навыки коммуникации.
# Макс. кол-во баллов: 16
#
# Заработанные баллы: 14
#
# Процентное отношение: 87,5%
#
# Безопасность. Управление
# Макс. кол-во баллов: 7
#
# Заработанные баллы: 6
#
# Процентное отношение: 85,7%
#
# Программное обеспечение. Windows
# Макс. кол-во баллов: 41
#
# Заработанные баллы: 28
#
# Процентное отношение: 68,3%
#
# Безопасность. Основы безопасности
# Макс. кол-во баллов: 29
#
# Заработанные баллы: 23
#
# Процентное отношение: 79,3%
#
# Компьютерные системы. Рабочие станции
# Макс. кол-во баллов: 1
#
# Заработанные баллы: 1
#
# Процентное отношение: 100%
#
# Программное обеспечение. ОС компьютера
# Макс. кол-во баллов: 18
#
# Заработанные баллы: 13
#
# Процентное отношение: 72,2%
#
# Программное обеспечение. Виртуализация
# Макс. кол-во баллов: 1
#
# Заработанные баллы: 1
#
# Процентное отношение: 100%
#
# Компьютерные системы. Периферийные устройства
# Макс. кол-во баллов: 1
#
# Заработанные баллы: 1
#
# Процентное отношение: 100%
#
# Программное обеспечение. ОС мобильных устройств
# Макс. кол-во баллов: 0
#
# Заработанные баллы: 0
#
# Процентное отношение: 0,0%
#
# Компьютерные системы. Ноутбуки и мобильные устройства
# Макс. кол-во баллов: 2
#
# Заработанные баллы: 2
#
# Процентное отношение: 100%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
